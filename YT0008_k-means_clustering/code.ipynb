# %%
from kmeans import *
from plot_utils import *

data = generate_data()

# %%
model = KMeans(k=3)
history = model.fit(data)
predictions = model.predict(data)

# Visualize the results
plot_clusters(data=data, labels=predictions, centroids=model.centroids)

# %%
plot_fit_history(data=data, history=history)

# %%
model = KMeans(k=3)
history = model.multiple_run(data)
predictions = model.predict(data)

# Visualize the results
plot_clusters(data=data, labels=predictions, centroids=model.centroids)

# %%
plot_multiple_run_history(history=history)

# %%
history = model.find_optimal_k(data=data)
plot_optimal_k(history=history)
